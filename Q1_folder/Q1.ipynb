# %%
from py.functions import load_data, basic_clean, train_test_split_time
import pandas as pd

# %% [markdown]
# # Q1  - Baseline Model for Financial Time Series
#
# In this question, I build a simple baseline model to predict future closing prices using past values. This helps me understand whether the dataset has predictable structre before trying more advanced models.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("khushikyad001/finance-and-economics-dataset-2000-present")

print("Path to dataset files:", path)

# %%
df = load_data("finance.csv")
df = basic_clean(df)
df.head()

# %%
df['Close_lag1'] = df['Close'].shift(1)
df['Close_lag2'] = df['Close'].shift(2)
df['Close_lag3'] = df['Close'].shift(3)
df = df.dropna()

# %%
from sklearn.linear_model import LinearRegression

train, test = train_test_split_time(df)

X_train = train[['Close_lag1', 'Close_lag2', 'Close_lag3']]
y_train = train['Close']

X_test = test[['Close_lag1', 'Close_lag2', 'Close_lag3']]
y_test = test['Close']

model = LinearRegression()
model.fit(X_train, y_train)

preds = model.predict(X_test)

# %% [markdown]
# I use Linear Regression as a baseline model because it is simple and interpretable. It gives a quick idea of whether the lag features contain useful predictive information.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mae = mean_absolute_error(y_test, preds)
rmse = np.sqrt(mean_squared_error(y_test, preds))
mae, rmse

# %% [markdown]
# MAE and RMSE tell me how far off the model's predictions are from the true values. Lower values mean better performance.
